# %%
# !pip install chroma
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chroma in /home/tawnos/.local/lib/python3.12/site-packages (0.2.0)

# %%
# !pip install "langchain-chroma>=0.1.2"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-chroma>=0.1.2
#   Using cached langchain_chroma-0.1.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 (from langchain-chroma>=0.1.2)
#   Using cached chromadb-0.5.11-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain-chroma>=0.1.2)
#   Using cached fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting langchain-core<0.4,>=0.1.40 (from langchain-chroma>=0.1.2)
#   Using cached langchain_core-0.3.8-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain-chroma>=0.1.2)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting build>=1.0.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached build-1.2.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting pydantic>=1.9 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached chroma_hnswlib-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached uvicorn-0.31.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Downloading posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/lib/python3/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (4.10.0)
# Collecting onnxruntime>=1.14.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached onnxruntime-1.19.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached tokenizers-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Collecting tqdm>=4.65.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: overrides>=7.3.1 in /home/tawnos/.local/lib/python3.12/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (7.7.0)
# Collecting importlib-resources (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached grpcio-1.66.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting bcrypt>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting typer>=0.9.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting tenacity>=8.2.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/lib/python3/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached mmh3-5.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached orjson-3.10.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Requirement already satisfied: httpx>=0.27.0 in /home/tawnos/.local/lib/python3.12/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/lib/python3/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (13.7.1)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<1,>=0.95.2->langchain-chroma>=0.1.2)
#   Using cached starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4,>=0.1.40->langchain-chroma>=0.1.2)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.2.0,>=0.1.125 (from langchain-core<0.4,>=0.1.40->langchain-chroma>=0.1.2)
#   Using cached langsmith-0.1.130-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/lib/python3/dist-packages (from langchain-core<0.4,>=0.1.40->langchain-chroma>=0.1.2) (24.0)
# Collecting tenacity>=8.2.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /home/tawnos/.local/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (4.6.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /home/tawnos/.local/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (1.0.6)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (3.6)
# Requirement already satisfied: sniffio in /home/tawnos/.local/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tawnos/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1.40->langchain-chroma>=0.1.2) (2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/tawnos/.local/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (1.8.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (2.31.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (2.0.7)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.1.40->langchain-chroma>=0.1.2)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/lib/python3/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (68.1.2)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached pydantic_core-2.23.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/lib/python3/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (2.17.2)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (8.1.6)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached httptools-0.6.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached uvloop-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached watchfiles-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached websockets-13.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting zipp>=0.5 (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2) (0.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma>=0.1.2)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached langchain_chroma-0.1.4-py3-none-any.whl (10 kB)
# Using cached chromadb-0.5.11-py3-none-any.whl (603 kB)
# Using cached chroma_hnswlib-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Using cached fastapi-0.115.0-py3-none-any.whl (94 kB)
# Using cached langchain_core-0.3.8-py3-none-any.whl (400 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
# Using cached build-1.2.2-py3-none-any.whl (22 kB)
# Using cached grpcio-1.66.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached langsmith-0.1.130-py3-none-any.whl (294 kB)
# Using cached mmh3-5.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
# Using cached onnxruntime-1.19.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
# Using cached opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Using cached opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Using cached opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Using cached orjson-3.10.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 1.1 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached starlette-0.38.6-py3-none-any.whl (71 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached tokenizers-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached uvicorn-0.31.0-py3-none-any.whl (63 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
# Using cached huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
# Using cached importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvloop-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
# Using cached watchfiles-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
# Using cached websockets-13.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
# Using cached zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: pypika, mpmath, monotonic, flatbuffers, durationpy, zipp, wrapt, websockets, uvloop, uvicorn, tqdm, tenacity, sympy, shellingham, requests-toolbelt, requests-oauthlib, python-dotenv, pyproject_hooks, pydantic-core, pyasn1, protobuf, orjson, opentelemetry-util-http, numpy, mmh3, jsonpatch, importlib-resources, humanfriendly, httptools, grpcio, fsspec, filelock, cachetools, bcrypt, backoff, asgiref, annotated-types, watchfiles, starlette, rsa, pydantic, pyasn1-modules, posthog, opentelemetry-proto, importlib-metadata, huggingface-hub, googleapis-common-protos, deprecated, coloredlogs, chroma-hnswlib, build, typer, tokenizers, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, langsmith, google-auth, fastapi, opentelemetry-semantic-conventions, opentelemetry-instrumentation, langchain-core, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
# Successfully installed annotated-types-0.7.0 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2 cachetools-5.5.0 chroma-hnswlib-0.7.6 chromadb-0.5.11 coloredlogs-15.0.1 deprecated-1.2.14 durationpy-0.9 fastapi-0.115.0 filelock-3.16.1 flatbuffers-24.3.25 fsspec-2024.9.0 google-auth-2.35.0 googleapis-common-protos-1.65.0 grpcio-1.66.2 httptools-0.6.1 huggingface-hub-0.25.1 humanfriendly-10.0 importlib-metadata-8.4.0 importlib-resources-6.4.5 jsonpatch-1.33 kubernetes-31.0.0 langchain-chroma-0.1.4 langchain-core-0.3.8 langsmith-0.1.130 mmh3-5.0.1 monotonic-1.6 mpmath-1.3.0 numpy-1.26.4 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 orjson-3.10.7 posthog-3.7.0 protobuf-4.25.5 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.9.2 pydantic-core-2.23.4 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rsa-4.9 shellingham-1.5.4 starlette-0.38.6 sympy-1.13.3 tenacity-8.5.0 tokenizers-0.20.0 tqdm-4.66.5 typer-0.12.5 uvicorn-0.31.0 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.1 wrapt-1.16.0 zipp-3.20.2

# %%
# !pip install langchain-openai
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-openai
#   Using cached langchain_openai-0.2.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /home/tawnos/.local/lib/python3.12/site-packages (from langchain-openai) (0.3.8)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai)
#   Using cached openai-1.51.0-py3-none-any.whl.metadata (24 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Using cached tiktoken-0.7.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain-core<0.4,>=0.3->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tawnos/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/tawnos/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (0.1.130)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/lib/python3/dist-packages (from langchain-core<0.4,>=0.3->langchain-openai) (24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/tawnos/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/tawnos/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/lib/python3/dist-packages (from langchain-core<0.4,>=0.3->langchain-openai) (4.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/tawnos/.local/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tawnos/.local/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.40.0->langchain-openai)
#   Using cached jiter-0.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /home/tawnos/.local/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/tawnos/.local/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.5)
# Collecting typing-extensions>=4.7 (from langchain-core<0.4,>=0.3->langchain-openai)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Using cached regex-2024.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /usr/lib/python3/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.6)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /home/tawnos/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tawnos/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-openai) (2.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tawnos/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tawnos/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tawnos/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tawnos/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-openai) (2.23.4)
# Using cached langchain_openai-0.2.1-py3-none-any.whl (49 kB)
# Using cached openai-1.51.0-py3-none-any.whl (383 kB)
# Using cached tiktoken-0.7.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Using cached jiter-0.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
# Using cached regex-2024.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (797 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, regex, jiter, tiktoken, openai, langchain-openai
# Successfully installed jiter-0.5.0 langchain-openai-0.2.1 openai-1.51.0 regex-2024.9.11 tiktoken-0.7.0 typing-extensions-4.12.2

# %%
# !pip install pypdf
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pypdf
#   Downloading pypdf-5.0.1-py3-none-any.whl.metadata (7.4 kB)
# Downloading pypdf-5.0.1-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 7.3 MB/s eta 0:00:009.3 MB/s eta 0:00:01
# Installing collected packages: pypdf
# Successfully installed pypdf-5.0.1

# %%
import chromadb
from uuid import uuid4
from langchain_core.documents import Document
from langchain_chroma import Chroma

# %%
persistent_client = chromadb.PersistentClient()
collection = persistent_client.get_or_create_collection("collection_name")
collection.add(ids=["1", "2", "3"], documents=["a", "b", "c"])

embeddings = open("striped.txt", "r")

# %%
vector_store_from_client = Chroma(
    client = persistent_client,
    collection_name = "collection_name",
    embedding_function = embeddings,
)

# %%
document_1 = Document(
    Page_content="the Weather forecast for tomorrow is clody with overcast",
    metadata={"source": "news"},
    id=1
)
document_2 = Document(
    Page_content="the movie was great!",
    metadata={"source": "news"},
    id=2
)

# %%
ocuments = [
    document_1
    document_2
]

# %%
uuids = [str(uuid4()) for _ in range(len(documents))]

# %%
vector_store.add_documents(documents=documents, id=uudis)
