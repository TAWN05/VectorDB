# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install "langchain-chroma>=0.1.2"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.5 MB/s eta 0:00:001.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 3.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 12.7 MB/s eta 0:00:00MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.2 MB/s eta 0:00:0031m38.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 23.6 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.2 MB/s eta 0:00:000m eta 0:00:01:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.2 MB/s eta 0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 70.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.5/281.5 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 83.6 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-openai
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain_openai-0.2.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached openai-1.51.0-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached tiktoken-0.7.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached jiter-0.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached regex-2024.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ...

# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠴ pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   2% ▕                ▏ 6.3 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   7% ▕█               ▏  19 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   8% ▕█               ▏  22 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...  14% ▕██              ▏  37 MB/274 MB                  pulling manifest
# ...

# %%
import chromadb
from uuid import uuid4
from langchain_core.documents import Document
from langchain_chroma import Chroma
import ollama 
from langchain.text_splitter import CharacterTextSplitter

# %%
embedding = ollama.embeddings(model='nomic-embed-text')

# %%
persistent_client = chromadb.PersistentClient()
collection = persistent_client.get_or_create_collection("collection_name")
#client = chromadb.Client()

# %%
document_1 = """The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.

Building an exciting new project with LangChain - come check it out!
"""
document_2 = "Building an exciting new project with LangChain - come check it out!"
documents = [document_1, document_2]
metadatas_1 = {"source": "news"}
metadatas_2 = {"source": "news"}
metadatas = [metadatas_1, metadatas_2]
id1 = "id1"
id2 = "id2"
ids = [id1, id2]
collection.update(
    documents = documents,
    metadatas = [{"source": "news"},{"source": "news"}],
    ids = ["id1","id2"],
)
#embedding = ollama.embeddings(model='nomic-embed-text')
#print(embedding)

# %%
vector_store = Chroma(
    collection_name = "collection_name",
    embedding_function = embedding,
)
"""doc_creator = CharacterTextSplitter(separator = "\n\n",)

uuids = [str(uuid4()) for _ in range(len(documents))]
pages = doc_creator.split_text(documents)
print(pages)
for x in documents:
    texts = doc_creator.create_documents([x], metadatas = metadatas)
    print(document)
vector_store.add_documents(documents=documents, ids=uuids)"""
# Out:
# 'doc_creator = CharacterTextSplitter(separator = "\n\n",)\n\nuuids = [str(uuid4()) for _ in range(len(documents))]\npages = doc_creator.split_text(documents)\nprint(pages)\nfor x in documents:\n    texts = doc_creator.create_documents([x], metadatas = metadatas)\n    print(document)\nvector_store.add_documents(documents=documents, ids=uuids)'

# %%
vector_store_from_client = Chroma(
    client = persistent_client,
    collection_name = "collection_name",
    embedding_function = embedding,
)

# %%
results = collection.query(
    query_texts=["exciting new project"],
    n_results=1,
)
results
# Out:
# {'ids': [['8']],
#  'distances': [[1.0296292304992676]],
#  'metadatas': [[{'source': 'news'}]],
#  'embeddings': None,
#  'documents': [['Building an exciting new project with LangChain - come check it out!']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
results = vector_store.similarity_search_with_score(
    "Will it be hot tomorrow?", k=1, filter={"source": "news"}
)
for res, score in results:
    print(f"* [SIM={score:3f}] {res.page_content} [{res.metadata}]")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results = vector_store.similarity_search_with_score(
#       2     "Will it be hot tomorrow?", k=1, filter={"source": "news"}
#       3 )
#       4 for res, score in results:
#       5     print(f"* [SIM={score:3f}] {res.page_content} [{res.metadata}]")
#
# File ~/.local/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:679, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     671     results = self.__query_collection(
#     672         query_texts=[query],
#     673         n_results=k,
#    (...)
#     676         **kwargs,
#     677     )
#     678 else:
# --> 679     query_embedding = self._embedding_function.embed_query(query)
#     680     results = self.__query_collection(
#     681         query_embeddings=[query_embedding],
# ...
