# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏ 619 KB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   2% ▕                ▏ 4.5 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   3% ▕                ▏ 7.2 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   3% ▕                ▏ 7.5 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   3% ▕                ▏ 7.5 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   3% ▕                ▏ 7.9 MB/274 MB                  pulling manifest
# ...

# %%
from pypdf import PdfReader
import ollama as ol

# %%
def strip(filename):
    text = ""
    chunked = []
    p = ""
    joined = ""
    reader = PdfReader(filename)
    for page in reader.pages:
        text += page.extract_text() + "\n"
    readtext = text.split("\xa0")
    x = " ".join(readtext)
    chunked_text = x.split('.\n')
    for x in chunked_text:
        chunked += [p]
        p = ""
        for y in x:
            p += y.replace("\n", " ")
    return chunked

# %%
embed = []
prompts = strip("1540157347-HarlanEllison-IHaveNoMouthandIMustScream.pdf")
for d in prompts:
    embed += [ol.embeddings(model='nomic-embed-text', prompt=d)]
embeds = open("striped text", "a")
embed.append(embeds)

# %%
print(strip("1540157347-HarlanEllison-IHaveNoMouthandIMustScream.pdf"))
# Out:
# ['', '5/18/2015 I Have No Mouth, and I Must Scream by Harlan Ellison http://hermiene.net/short\xadstories/i_have_no_mouth.html 1/11 I Have No Mouth, and I Must Scream by Harlan Ellison Limp, the body of Gorrister hung from the pink palette; unsupported—hanging high above us in the computer chamber; and it did not shiver in the chill, oily breeze that blew eternally through the main cavern. The body hung head down, attached to the underside of the palette by the sole of its right foot. It had been drained of blood through a precise incision made from ear to ear under the lantern jaw. There was no blood on the reflective surface of the metal floor', 'When Gorrister joined our group and looked up at himself, it was already too late for us to realize that, once again, AM had duped us, had had its fun; it had been a diversion on the part of the machine. Three of us had vomited, turning away from one another in a reflex as ancient as the nausea that had produced it', 'Gorrister went white.
# ...

# %%
print(embed)
# Out:
# [{'embedding': []}, {'embedding': [1.0683844089508057, 0.8124524354934692, -3.0997190475463867, -1.1939409971237183, 0.07308204472064972, 1.1100504398345947, -0.6391985416412354, 1.4776177406311035, -0.9085307717323303, 0.129776269197464, -0.6533244848251343, 0.986128568649292, 0.48833167552948, 0.930374026298523, 0.463143527507782, -0.7072566747665405, 0.49382027983665466, 0.06294266879558563, -0.24141232669353485, 0.7161867618560791, -1.3950237035751343, -0.9649356007575989, -0.16756412386894226, 0.6240705251693726, 1.7582411766052246, 0.6561057567596436, -0.9229442477226257, -0.12377192825078964, -0.9208899140357971, 0.24997036159038544, 0.8089544177055359, -0.14440461993217468, -0.20068207383155823, -0.38765209913253784, -0.43053337931632996, -1.6273918151855469, 0.6065337657928467, 0.5816961526870728, 0.7852783203125, 0.6340510845184326, 0.9137228727340698, -0.2290174663066864, -0.6186867952346802, -1.2629752159118652, -0.1320629119873047, 0.3482620120048523, 0.18627609312534332
# ...

# %%
with open(r'embedstriped.txt', 'w') as fp:
    for item in embed:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
with open(r'sstriped.txt', 'w') as fp:
    for item in prompts:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done
